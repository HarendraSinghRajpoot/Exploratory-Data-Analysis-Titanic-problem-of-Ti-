# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers
# - Answering questions

# %% [markdown]
# **DATASET** - TITANIC

# %% [markdown]
# **Data Dictionary:**
#
# - **PassengerId:** Unique identifier for each passenger
# - **Survived:** Survival status (0 = No, 1 = Yes)
# - **Pclass:** Ticket class (1 = 1st, 2 = 2nd, 3 = 3rd)
# - **Name:** Name of the passenger
# - **Sex:** Gender of the passenger
# - **Age:** Age of the passenger
# - **SibSp:** Number of siblings/spouses aboard the Titanic
# - **Parch:** Number of parents/children aboard the Titanic
# - **Ticket:** Ticket number
# - **Fare:** Passenger fare
# - **Cabin:** Cabin number
# - **Embarked:** Port of Embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)

# %% [markdown]
# ### Column Types
#
# - **Numerical** - Age,Fare,PassengerId
# - **Categorical** - Survived, Pclass, Sex, SibSp, Parch,Embarked
# - **Mixed** - Name, Ticket, Cabin

# %% [markdown]
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### Remember it is an iterative process

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_df = pd.read_csv('test.csv')

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Display basic information about the datasets
print(train_df.info())
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %% [markdown]
# ### Initial Exploration

# %%
# Display summary statistics
train_df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
test_df.describe(include='all')
# Out:
#         PassengerId      Pclass              Name   Sex         Age  \
# count    418.000000  418.000000               418   418  332.000000
# unique          NaN         NaN               418     2         NaN
# top             NaN         NaN  Kelly, Mr. James  male         NaN
# freq            NaN         NaN                 1   266         NaN
# mean    1100.500000    2.265550               NaN   NaN   30.272590
# std      120.810458    0.841838               NaN   NaN   14.181209
# min      892.000000    1.000000               NaN   NaN    0.170000
# 25%      996.250000    1.000000               NaN   NaN   21.000000
# 50%     1100.500000    3.000000               NaN   NaN   27.000000
# 75%     1204.750000    3.000000               NaN   NaN   39.000000
# max     1309.000000    3.000000               NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# ...

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values in train dataset
print(train_df.isnull().sum())
print("*"*25)
# Check for missing values in test dataset
print(test_df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# *************************
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### In the train data --
# - 177 missing values are present in "Age" feature
# - 687 missing values are present in "Cabin" feature
# - 2 missing values are present in "Embarked" feature
#
# ### In the Test data --
# - 86 missing values are present in "Age" feature
# - 1 missing value is present in "Fare" feature
# - 327 missing values are present in "Cabin" feature

# %% [markdown]
# ### Duplicates

# %%
train_df.duplicated().sum()
# Out:
# 0

# %%
test_df.duplicated().sum()
# Out:
# 0

# %%
## Checking duplicates without considering the passenger id into the analysis

# %%
train_df.duplicated(subset=train_df.columns.difference(['PassengerId'])).sum()
# Out:
# 0

# %%
test_df.duplicated(subset=test_df.columns.difference(['PassengerId'])).sum()
# Out:
# 0

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# - Aur thoda bohot feature engineering aur bivariate analysis bhi sath sath chalti rehti h

# %% [markdown]
# ### 1. AGE

# %%
### Age - with mean and median imputation

# %%
train_df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.histplot(train_df["Age"], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers #can be confirmed using a boxplot
# - The mean and median i.e. most of the passengers were aged around 30.
# - THere were many children too i.e. a lot of passengers were aged < 10.

# %% [markdown]
# ### Treatment of missing values before proceeding further

# %%
##missing value imputation using mean and median on "Age"

# %%
mean_age = train_df['Age'].mean()
median_age = train_df['Age'].median()

# %%
train_df['Age_median'] = train_df['Age'].fillna(median_age)
train_df['Age_mean'] = train_df['Age'].fillna(mean_age)

# %%
# zyada difference in variance between imputed and original features will lead to introduction of new outliers and bias in the imputed feature
print('Original Age variable variance: ', train_df['Age'].var())
print('Age Variance after median imputation: ', train_df['Age_median'].var())
print('Age Variance after mean imputation: ', train_df['Age_mean'].var())

#Age still needs to be rectified
# Out:
# Original Age variable variance:  211.0191247463081
# Age Variance after median imputation:  169.51249827942328
# Age Variance after mean imputation:  169.05239993721085

# %%
#mean aur median se imputed values ka distribution origianl 'Age' k distribution se kaafi different h, isiliye age ko iss method se impute karna sahi nhi
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
train_df['Age'].plot(kind='kde', ax=ax)

# variable imputed with the median
train_df['Age_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
train_df['Age_mean'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
train_df['Age'].plot(kind='box') # original age mai outliers
# Out:
# <Axes: >

# %%
train_df['Age_median'].plot(kind='box') # outliers badh gye h kaafi
# Out:
# <Axes: >

# %%
train_df['Age_mean'].plot(kind='box') # outliers badh gye h kaafi
# Out:
# <Axes: >

# %%
## Age - Random Imputation

# %%
#original age ko new feature "Age_imputed" mai store kar rhe h jisse ki orginal features pe changes naa karke new feature pe saare changes karenge aur fir compare kar sakenge
train_df['Age_random'] = train_df['Age']
test_df['Age_random'] = test_df['Age']

# %%
#Create 'Age_random' column
train_df['Age_random'] = train_df['Age']
test_df['Age_random'] = test_df['Age']

# Define a function to fill missing values with random samples from the same feature
def fill_missing_with_random(df, column_name):
    df[column_name + '_random'] = df[column_name]
    missing_count = df[column_name].isnull().sum()
    df.loc[df[column_name].isnull(), column_name + '_random'] = np.random.choice(df[column_name].dropna().values, missing_count)
    return df

# Fill missing values in 'Age_random' with random values from 'Age'
train_df = fill_missing_with_random(train_df, 'Age')
test_df = fill_missing_with_random(test_df, 'Age')

# %%
# very close distribution between original and imputed values 
sns.distplot(train_df['Age'],label='Original',hist=False)
sns.distplot(train_df['Age_random'],label = 'Imputed',hist=False)

plt.legend()
plt.show()
# Out:
# C:\Users\sriva\AppData\Local\Temp\ipykernel_25580\4068277526.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['Age'],label='Original',hist=False)
# C:\Users\sriva\AppData\Local\Temp\ipykernel_25580\4068277526.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
print('Original Age variable variance: ', train_df['Age'].var())
print('Age Variance after median imputation: ', train_df['Age_random'].var())
# its okkk
# Out:
# Original Age variable variance:  211.0191247463081
# Age Variance after median imputation:  209.58651842242654

# %%
train_df.corr() #covariance and correlation are also equal for original and imputed values --> good to go with
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# Age_median      0.034212 -0.064910 -0.339898  1.000000 -0.233296 -0.172482
# Age_mean        0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# Age_random     -0.023072 -0.059847 -0.306493  1.000000 -0.242149 -0.164790
#
#                  Fare  Age_median  Age_mean  Age_random
# PassengerId  0.012658    0.034212  0.033207   -0.023072
# ...

# %%
# Plot both boxplots in subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Original Age boxplot
train_df['Age'].plot(kind='box', ax=axes[0], title='Original Age')

# Age_random boxplot
train_df['Age_random'].plot(kind='box', ax=axes[1], title='Age with Random Imputation')

plt.tight_layout()
plt.show()


# THEEK THAAK H MAAMLA

# %% [markdown]
# **Studying Outliers -**

# %%
## outliers
train_df[train_df['Age'] > 60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %% [markdown]
# **outliers inference** -
# - mostly male passengers in the age group of > 60
# - only one managed to survive

# %% [markdown]
# ### 2. FARE

# %%
train_df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
sns.histplot(train_df["Fare"],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %% [markdown]
# **conclusions**
#
# - The data is highly(positively) skewed
# - The average fare for the titanic trip was around 32 dollors but 50 % of the people paid <= 15 dollors and 75% people paid less than 31 dollors.
# - Fare col actually contains the group fare and not the individual fare(This migth be and issue) beacause a lot of people have siblings, parents and child
# - We need to create a new col called individual fare

# %%
train_df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
sns.boxplot(train_df["Fare"]) #kaafi outliers h
# Out:
# <Axes: >

# %% [markdown]
# ### Studying outliers - just taking an overview of outliers

# %%
print(len(train_df[train_df['Fare'] > 80])) #80 se zyada fare dene wale
print(len(train_df[train_df['Fare'] > 150])) #150 se zyada fare dene wale
print(len(train_df[train_df['Fare'] > 250]))
print(len(train_df[train_df['Fare'] > 500])) #500 se zyada fare dene wale
# Out:
# 74
# 29
# 9
# 3

# %%
train_df[train_df['Fare'] > 500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      Age_median  Age_mean  Age_random
# 258        35.0      35.0        35.0
# 679        36.0      36.0        36.0
# 737        35.0      35.0        35.0

# %%
train_df["Ticket"].nunique()
# Out:
# 681

# %%
train_df[(train_df['Fare'] > 500) & (train_df['Survived'] == 1)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age_median, Age_mean, Age_random]
# Index: []

# %%
print(len(train_df[train_df['Fare'] > 150]))
print(len(train_df[(train_df['Fare'] > 150) & (train_df['Survived'] == 1)]))
# Out:
# 29
# 20

# %%
train_df[(train_df['Fare'] > 150) & (train_df['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 88            89         1       1
# 258          259         1       1
# 268          269         1       1
# 299          300         1       1
# 305          306         1       1
# 311          312         1       1
# 318          319         1       1
# 341          342         1       1
# 380          381         1       1
# 609          610         1       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 708          709         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
# 856          857         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 88                          Fortune, Miss. Mabel Helen  female  23.00      3
# ...

# %%
print(len(train_df[(train_df['Fare'] > 80)]))
print(len(train_df[(train_df['Fare'] > 80) & (train_df['Survived'] == 1)]))
# Out:
# 74
# 57

# %%
(train_df[(train_df['Fare'] > 80) & (train_df['Survived'] == 1)])
# Out:
#      PassengerId  Survived  Pclass  \
# 31            32         1       1
# 88            89         1       1
# 195          196         1       1
# 215          216         1       1
# 224          225         1       1
# 230          231         1       1
# 257          258         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 291          292         1       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 310          311         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 375          376         1       1
# 380          381         1       1
# ...

# %%
train_df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics:** Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations:** Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values:** Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion:** Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### 3. Survived (Target Feature)

# %%
# Plot the distribution of the 'Survived' variable
sns.countplot(data=train_df, x='Survived')
plt.title('Distribution of Survival')
plt.show()

# %%
train_df["Survived"].value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %% [markdown]
# ### Conclusion
# - 61% passengers died in the titanic accident
# - 38% survived the accident
# - The dataset is slightly imbalanced when it comes to solving the classification problem

# %% [markdown]
# ### 4. Pclass - passenger class

# %%
# Plot the distribution of 'Pclass'
sns.countplot(data=train_df, x='Pclass')
plt.title('Distribution of Passenger Class')
plt.show()

# %%
train_df["Pclass"].value_counts(normalize=True)
# Out:
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: Pclass, dtype: float64

# %% [markdown]
# ### Conclusion
# - 24% passengers travelled in class 1
# - 20% passengers travelled in class 2
# - 55% passengers travelled in class 3

# %% [markdown]
# ### 5. Sex

# %%
# Plot the distribution of 'Sex'
sns.countplot(data=train_df, x='Sex')
plt.title('Distribution of Gender')
plt.show()

# %%
train_df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train_df["Sex"].value_counts(normalize=True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %% [markdown]
# ### Inferences -
# - No. of Male passengers = 577
# - No. of Female passengers = 314
#
# **The distribution of male:female is around 64:35 = 1.8285:1**

# %% [markdown]
# ### 6. Embarked

# %%
# Plot the distribution of 'Embarked'
sns.countplot(data=train_df, x='Embarked')
plt.title('Distribution of Embarked')
plt.show()

# %%
train_df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ### Missing value treatment in Embarked

# %%
# Fill missing values for 'Embarked' with the most frequent value
train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)

# %%
train_df["Embarked"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### conclusions-
# - 646 passengers boarded from southampton
# - 168 passengers boarded from cherbourg
# - 77 passengers boarded from southampton
#
# C = Cherbourg, Q = Queenstown, S = Southampton

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 7. Cabin

# %% [markdown]
# **ONE CAN DEAL WITH THE "CABIN" FEATURE SEPARATELY SINCE IT CONTAINS MOSTLY THE MISSING DATA OR ONE CAN ALSO DROP THIS FEATURE FROM THE ANALYSIS (IF THEY FIND IT NOT USEFUL)- 77% data missing**

# %%
train_df["Cabin"].isnull().mean()
# Out:
# 0.7710437710437711

# %%
train_df["Cabin"].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
train_df["Cabin"].nunique() #147 unique categories
# Out:
# 147

# %%
## Treating the missing values in the Cabin Feature

# %%
# Fill missing values in 'Cabin' with 'Missing'
train_df['Cabin'] = train_df['Cabin'].fillna('Missing')
test_df['Cabin'] = test_df['Cabin'].fillna('Missing')

# %%
train_df["Cabin"]
# Out:
# 0      Missing
# 1          C85
# 2      Missing
# 3         C123
# 4      Missing
#         ...
# 886    Missing
# 887        B42
# 888    Missing
# 889       C148
# 890    Missing
# Name: Cabin, Length: 891, dtype: object

# %%
# Extract the first letter of the cabin code to create the 'Deck' feature
train_df['Deck'] = train_df['Cabin'].apply(lambda x: x[0])
test_df['Deck'] = test_df['Cabin'].apply(lambda x: x[0])

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Check the distribution of 'Deck'
print(train_df['Deck'].value_counts())
print("*"*30)
print(test_df['Deck'].value_counts())
# Out:
# M    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: Deck, dtype: int64
# ******************************
# M    327
# C     35
# B     18
# D     13
# E      9
# F      8
# A      7
# G      1
# Name: Deck, dtype: int64

# %% [markdown]
# **Cabin feature is now of no use to us since we have created a new feature "Deck" using the "Cabin" feature which a lot less no. of categories and is now manageable.**

# %% [markdown]
# ### 8. Sibsp and Parch - siblings/spouse and parents/children

# %% [markdown]
# ### siblings and parents/children are two features that can be combined to form a single new feature as family

# %%
# Create a new feature 'FamilySize'
train_df['FamilySize'] = train_df['SibSp'] + train_df['Parch'] + 1 # 1 wo insaan khud
test_df['FamilySize'] = test_df['SibSp'] + test_df['Parch'] + 1 # 1 wo insaan khud

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df["FamilySize"].value_counts()
# Out:
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: FamilySize, dtype: int64

# %% [markdown]
# ### Now we can create an Individual Fare feature using the "Family size" feature

# %%
# Create 'FarePerPerson' feature
train_df['FarePerPerson'] = train_df['Fare'] / train_df['FamilySize']
test_df['FarePerPerson'] = test_df['Fare'] / test_df['FamilySize']

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Also creating a new feature as "Family_type" signifying the size of the family

# %%
def myfunc(num):
    if num == 1:
        #alone
        return 0
    elif num >1 and num <=4:
        # small family
        return 1
    else:
        # large family
        return 2
    
# jaha bhi family size =1 hai waha alone ki category bana rhe h aur usse 0 se represent kar rhe h (matlab kam weightage de rhe h), jaha bhi family size >=1 and <=4 h waha new category small ko 1 se represent kar rhe h (thoda zyada weightage de rhe h) , aur 
# jaha bhi family size > 4 h waha hum log large family k corresponding 2 no. se represent kar rhe h (sabse zyada weightage)

# %%
train_df['Family_type'] = train_df['FamilySize'].apply(myfunc) #family_type feature ko construct kar rhe h aur usme upar wale family size k nomenclature k according values fill kar rhe h

# %%
train_df["Family_type"].value_counts()
# Out:
# 0    537
# 1    292
# 2     62
# Name: Family_type, dtype: int64

# %% [markdown]
# ### 9. Name

# %% [markdown]
# #### surname ko extract krte h

# %%
train_df['Name'].str.split(', ', expand=True)
# Out:
#              0                                           1
# 0       Braund                             Mr. Owen Harris
# 1      Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2    Heikkinen                                 Miss. Laina
# 3     Futrelle          Mrs. Jacques Heath (Lily May Peel)
# 4        Allen                           Mr. William Henry
# ..         ...                                         ...
# 886   Montvila                                 Rev. Juozas
# 887     Graham                        Miss. Margaret Edith
# 888   Johnston              Miss. Catherine Helen "Carrie"
# 889       Behr                             Mr. Karl Howell
# 890     Dooley                                 Mr. Patrick
#
# [891 rows x 2 columns]

# %%
train_df["Surnname"] = train_df['Name'].str.split(', ', expand=True)[0]

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Title ko extract karte h

# %%
train_df['Name'].str.split(', ', expand=True)[1].str.split('.', expand=True)
# Out:
#         0                                       1     2
# 0      Mr                             Owen Harris  None
# 1     Mrs   John Bradley (Florence Briggs Thayer)  None
# 2    Miss                                   Laina  None
# 3     Mrs           Jacques Heath (Lily May Peel)  None
# 4      Mr                           William Henry  None
# ..    ...                                     ...   ...
# 886   Rev                                  Juozas  None
# 887  Miss                          Margaret Edith  None
# 888  Miss                Catherine Helen "Carrie"  None
# 889    Mr                             Karl Howell  None
# 890    Mr                                 Patrick  None
#
# [891 rows x 3 columns]

# %%
train_df['Title'] = train_df['Name'].str.split(', ', expand=True)[1].str.split('.', expand=True)[0]

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df["Title"].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# the Countess      1
# Capt              1
# Ms                1
# Sir               1
# Lady              1
# Mme               1
# Don               1
# Jonkheer          1
# Name: Title, dtype: int64

# %% [markdown]
# **Title kaafi saare hai, aur inhe kam kiya jaa sakta h merge karke**

# %%
# Create a robust mapping dictionary
title_mapping = {
    'Mr': 'Mr',
    'Miss': 'Miss',
    'Mrs': 'Mrs',
    'Dr': 'Others',
    'Rev': 'Others',
    'Mlle': 'Others',
    'Major': 'Others',
    'Col': 'Others',
    'the Countess': 'Others',
    'Capt': 'Others',
    'Ms': 'Miss',
    'Sir': 'Others',
    'Lady': 'Others',
    'Mme': 'Others',
    'Don': 'Others',
    'Jonkheer': 'Others',
    'Dona': 'Others',
    'Countess': 'Others',
    'Mlle': 'Others',
    'Ms': 'Others',
    'Lady': 'Others'
}

# Ensure titles have no leading/trailing spaces and are properly cased
train_df['Title'] = train_df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False).str.strip()
#test_df['Title'] = test_df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False).str.strip()

# Map the titles according to the mapping dictionary
train_df['Title'] = train_df['Title'].map(title_mapping)
#test_df['Title'] = test_df['Title'].map(title_mapping)

# Handle any missing titles after mapping
train_df['Title'] = train_df['Title'].fillna('Others')
#test_df['Title'] = test_df['Title'].fillna('Others')

# Display the updated value counts
print(train_df['Title'].value_counts())
#print(test_df['Title'].value_counts())
# Out:
# Mr        557
# Miss      182
# Mrs       125
# Others     27
# Name: Title, dtype: int64

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### First Name ko extract karte h

# %%
train_df["First_Name"]=train_df['Name'].str.split(', ', expand=True)[1].str.split('.', expand=True)[1]

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.isnull().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age              177
# SibSp              0
# Parch              0
# Ticket             0
# Fare               0
# Cabin              0
# Embarked           0
# Age_median         0
# Age_mean           0
# Age_random         0
# Deck               0
# FamilySize         0
# FarePerPerson      0
# Family_type        0
# Surnname           0
# Title              0
# First_Name         0
# dtype: int64

# %% [markdown]
# ### Bivariate and Multivariate Analysis

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %% [markdown]
# ### Bivariate Analysis and Multivariate analysis also goes neck to neck

# %% [markdown]
# ### Age vs Survived

# %%
# Plot survival rates by Age and Passenger Class
plt.figure(figsize=(10, 6))
sns.boxplot(data=train_df, x='Survived', y='Age')
plt.title('Survival Rates by Age and Survived')
plt.show()

# %% [markdown]
# **The passengers who manage to survive and who died in this accident have almost the same range of age**

# %% [markdown]
# ### Impact of Passenger Class on the Survival and the Age

# %% [markdown]
# #### Passenger class vs Age distribution

# %%
# Plot Age and Passenger Class distribution first
plt.figure(figsize=(10, 6))
sns.boxplot(data=train_df, x='Pclass', y='Age')
plt.title('Survival Rates by Age and Passenger Class')
plt.show()

# %% [markdown]
# **Mostly elder people (>30) travelled in the first class - class 1 (more settled people can be assumed) and mostly the younger people travelled in the class 3**

# %%
# Plot survival rates by Age and Passenger Class
plt.figure(figsize=(10, 6))
sns.boxplot(data=train_df, x='Pclass', y='Age',hue='Survived')
plt.title('Survival Rates by Age and Passenger Class')
plt.show()

# %%
# Plot the distribution of 'Pclass'
sns.countplot(data=train_df, x='Pclass')
plt.title('Distribution of Passenger Class')
plt.show()

# %% [markdown]
# #### Box plot k size bada hone pe confuse naa ho ki uss category mai count zyada hoga logon ka, box plot count ki koi information nahi rakhta h

# %% [markdown]
# #### Kis passenger class mai kitne log the aur unme se bhi kitne log alive ya dead the? - ye information mujhe boxplot nahi de sakta
#
# **Use of UNSTACKED BAR PLOT -**

# %%
train_df[["Pclass", "Survived"]].value_counts() #crosstab zyada better information de payega
# Out:
# Pclass  Survived
# 3       0           372
# 1       1           136
# 3       1           119
# 2       0            97
#         1            87
# 1       0            80
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the counts for each Pclass and Survival status
pclass_survival_counts = train_df.groupby(['Pclass', 'Survived']).size().unstack().fillna(0)
# Calculate percentages
pclass_survival_percentages = pclass_survival_counts.div(pclass_survival_counts.sum(axis=1), axis=0) * 100

# Create the horizontal bar plot
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=train_df, y='Pclass', hue='Survived', palette='pastel', orient='h')

# Add percentage labels
for pclass in pclass_survival_counts.index:
    for survival_status in pclass_survival_counts.columns:
        count = pclass_survival_counts.loc[pclass, survival_status]
        percentage = pclass_survival_percentages.loc[pclass, survival_status]
        ax.text(
            count,
            ax.get_yaxis().get_majorticklocs()[pclass-1] + (-0.2 if survival_status == 0 else 0.2),
            f'{percentage:.1f}%',
            ha='center', va='center'
        )

# Add titles and labels
plt.title('Count of People from Respective Pclass and Their Survival Status')
plt.xlabel('Count')
plt.ylabel('Passenger Class (Pclass)')
plt.legend(title='Survived', labels=['No', 'Yes'])

# Show the plot
plt.show()

# %% [markdown]
# #### most of the survivors are from Passenger class 1 and then passenger class 2

# %% [markdown]
# ### Feature engineering - Age k groups bana k analysis dekhte h survival aur passenger class ki

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Bin the Age feature into meaningful categories
age_bins = [0, 18, 30,45, 60, 80]
age_labels = ['0-18', '19-30', '31-45','46-60','61-80']
train_df['AgeGroup'] = pd.cut(train_df['Age_random'], bins=age_bins, labels=age_labels)

# Create a faceted plot
g = sns.FacetGrid(train_df, col='AgeGroup', row='Pclass', margin_titles=True, height=4)
g.map_dataframe(sns.countplot, x='Survived', hue='Survived', palette='pastel')
g.add_legend()

# Add titles and labels
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Survival Count by Age Group and Passenger Class')

plt.show()

# %%
train_df["AgeGroup"].isnull().sum() #AgeGroup created
# Out:
# 0

# %% [markdown]
# #### Most of the passengers who managed to survive belong to the age group of 18-45 for every passenger class

# %% [markdown]
# ### Using cross tab - ek kaam ka function

# %%
pd.crosstab(train_df['Pclass'],train_df['Survived'],normalize='columns')*100
# Out:
# Survived          0          1
# Pclass
# 1         14.571949  39.766082
# 2         17.668488  25.438596
# 3         67.759563  34.795322

# %% [markdown]
# ### Interpretation
#
# **Survived = 0 (Did not survive)-**
#
# - Pclass 1: 14.57% of the passengers who did not survive were from the first class.
# - Pclass 2: 17.67% of the passengers who did not survive were from the second class.
# - Pclass 3: 67.76% of the passengers who did not survive were from the third class.
#
# **Survived = 1 (Survived)**
# - Pclass 1: 39.77% of the passengers who survived were from the first class.
# - Pclass 2: 25.44% of the passengers who survived were from the second class.
# - Pclass 3: 34.80% of the passengers who survived were from the third class.

# %% [markdown]
# ### Age vs Gender

# %%
# Plot survival rates by Age and Gender
plt.figure(figsize=(10, 6))
sns.boxplot(data=train_df, x='Sex', y='Age_random') #Age_random
plt.title('Survival Rates by Age and Gender')
plt.show()

# %% [markdown]
# ### The range of ages for male and females are almost equal

# %% [markdown]
# ### Age vs gender vs survival

# %%
# Plot survival rates by Age and Gender
plt.figure(figsize=(10, 6))
sns.boxplot(data=train_df, x='Sex', y='Age_random', hue='Survived')
plt.title('Survival Rates by Age and Gender')
plt.show()

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Boxplot
plt.figure(figsize=(10, 6))
sns.catplot(data=train_df, x='Sex', y='Age_random', hue='Survived', kind='box')
plt.title('Survival Rates by Age and Gender (Boxplot)')
plt.show()

# %%
pd.crosstab(train_df['Sex'],train_df['Survived'],normalize='columns')*100
# Out:
# Survived          0          1
# Sex
# female    14.754098  68.128655
# male      85.245902  31.871345

# %% [markdown]
# ### Mard zyada marr gye aur auratein zyada bach gayi

# %% [markdown]
# ### Fare and Passenger class

# %%
### Plot survival rates by Fare and Passenger Class
plt.figure(figsize=(10, 6))
sns.boxplot(data=train_df, x='Pclass', y='Fare')
plt.title('Survival Rates by Fare and Passenger Class')
plt.show()

# %% [markdown]
# #### Class 1 has the highest fare followed by class 2 and then class 3 (cheapest). Also some of the class 3 tickets have been priced higer

# %%
### Plot survival rates by Fare and Passenger Class
plt.figure(figsize=(10, 6))
sns.boxplot(data=train_df, x='Pclass', y='Fare', hue = "Sex")
plt.title('Survival Rates by Fare and Passenger Class')
plt.show()

# %% [markdown]
# #### the passengers who paid the high fare for the passenger class 1 are mostly females and there survival chances are also more - (Cannot be completely confirmed from the boxplot, therefore

# %% [markdown]
# #### The survival from the passenger class 1 is more as compared to the other two classes

# %%
# Calculate mean fare for each Pclass and Survived combination
mean_fare = pd.crosstab(train_df['Pclass'], train_df['Survived'], values=train_df['Fare'], aggfunc='mean')
median_fare = pd.crosstab(train_df['Pclass'], train_df['Survived'], values=train_df['Fare'], aggfunc='median')

print("Mean Fare:")
print(mean_fare)
print("\nMedian Fare:")
print(median_fare)
# Out:
# Mean Fare:
# Survived          0          1
# Pclass
# 1         64.684007  95.608029
# 2         19.412328  22.055700
# 3         13.669364  13.694887
#
# Median Fare:
# Survived      0        1
# Pclass
# 1         44.75  77.9583
# 2         13.00  21.0000
# 3          8.05   8.5167

# %% [markdown]
# #### upar wali analysis ko agar heatmap k maadhyam se dekhana ho toh

# %%
sns.heatmap(pd.crosstab(train_df['Pclass'], train_df['Survived'], values=train_df['Fare'], aggfunc='mean'),cmap='YlGn')
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# #### In general jo log survive kare iss accident mai unn logon ne mehenga ticket kharida tha - har ek passenger class mai

# %%
# Calculate mean fare for each Sex and Survived combination
mean_fare = pd.crosstab(train_df['Sex'], train_df['Survived'], values=train_df['Fare'], aggfunc='mean')
median_fare = pd.crosstab(train_df['Sex'], train_df['Survived'], values=train_df['Fare'], aggfunc='median')

print("Mean Fare:")
print(mean_fare)
print("\nMedian Fare:")
print(median_fare)
# Out:
# Mean Fare:
# Survived          0          1
# Sex
# female    23.024385  51.938573
# male      21.960993  40.821484
#
# Median Fare:
# Survived         0        1
# Sex
# female    15.24580  26.0000
# male       9.41665  26.2875

# %%
### Zyada paise auraton ne kharch kiye titanic pe ---> lekin kis class k liye kitne kharch kiye, ye crosstab bata dega

# %%
# Calculate mean fare for each Pclass and Sex
mean_fare = pd.crosstab(train_df['Sex'], train_df['Pclass'], values=train_df['Fare'], aggfunc='mean')
median_fare = pd.crosstab(train_df['Sex'], train_df['Pclass'], values=train_df['Fare'], aggfunc='median')

print("Mean Fare:")
print(mean_fare)
print("\nMedian Fare:")
print(median_fare)
# Out:
# Mean Fare:
# Pclass           1          2          3
# Sex
# female  106.125798  21.970121  16.118810
# male     67.226127  19.741782  12.661633
#
# Median Fare:
# Pclass         1     2       3
# Sex
# female  82.66455  22.0  12.475
# male    41.26250  13.0   7.925

# %% [markdown]
# #### Females ne zyada hi mehengaa ticket kharidaa tha passenger class 1 mai (ultra luxury ka saboot)

# %%
#swarm plot
plt.figure(figsize=(10, 6))
sns.swarmplot(data=train_df, x='Sex', y='Fare', hue='Survived', dodge=True)
plt.title('Distribution of Fare by Survival and Fare w.r.t Gender')
plt.xlabel('Gender')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### Survival wale logon ne in general zyada paise diye the marne walo k comparison mai --> feamales k case mai
# #### mardon k case mai kuch khaas fark nahi pada---> zyada paise deke bhi zyada tar mard maare gye

# %% [markdown]
# ### Embarked vs Survival

# %%
# Plot survival rates by Embarked and Survival
plt.figure(figsize=(10, 6))
sns.countplot(data=train_df, x='Embarked', hue='Survived', palette='pastel')
plt.title('Survival Rates by Embarked and Passenger Class')
plt.show()

# %% [markdown]
# #### Embarked utna essential column bhi nahi hona chahiye kyunki koi insaan kaha se ship ko board kar raha hai, uska accident mai zinda bachane ya marne mai koi information nahi de rha h

# %% [markdown]
# ### FamilySize vs Passenger class

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

survival_rates = train_df.groupby(['FamilySize', 'Pclass'])['Survived'].mean().reset_index()
survival_rates = survival_rates.pivot(index='FamilySize', columns='Pclass', values='Survived')

plt.figure(figsize=(10, 6))
sns.heatmap(survival_rates, annot=True, cmap='YlGn')
plt.title('Survival Rates by Family Size and Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Family Size')
plt.show()

# %% [markdown]
# - Passegner class 1 mai Family size 1-6 k beech k log the aur usme bhi maximum cases ki survival probability 0.5 se zyada hi thi
# - Passenger class 2 mai Family Size 1-6 k beech k log the aur usme bhi most of the cases mai survival probability 0.5 se zyada thi (except for alone person i.e. FamilySize = 1)
# - Passenger class 3 mai Family size 1-11 k beech k log the aur usme bhi most of the cases mai survival chances less than 40% percent the

# %%
# Plot survival rates by Family Size Group
plt.figure(figsize=(10, 6))
sns.barplot(data=train_df, x='FamilySize', y='Survived')
plt.title('Survival Rates by Family Size Group')
plt.show()

# %%
len((train_df[(train_df['Pclass'] ==1) & (train_df['Survived'] == 1)]))
# Out:
# 136

# %%
len((train_df[(train_df['Pclass'] ==1) & (train_df['Survived'] == 0)]))
# Out:
# 80

# %%
len((train_df[(train_df['Pclass'] ==1) & (train_df['FamilySize'] == 6)]))
# Out:
# 4

# %%
##############################################################################

# %% [markdown]
# ### Correlation between numerical features

# %%
sns.heatmap(train_df.corr())
# Out:
# <Axes: >

# %% [markdown]
# #### Survived and Age

# %%
# survived and age

train_df[train_df['Survived'] == 1]['Age'].plot(kind='kde',label='Survived')
train_df[train_df['Survived'] == 0]['Age'].plot(kind='kde',label='Not Survived')

plt.legend()
plt.show()

# %% [markdown]
# ### Deck vs Survived

# %%
pd.crosstab(train_df['Deck'],train_df['Survived'],normalize='index')
# Out:
# Survived         0         1
# Deck
# A         0.533333  0.466667
# B         0.255319  0.744681
# C         0.406780  0.593220
# D         0.242424  0.757576
# E         0.250000  0.750000
# F         0.384615  0.615385
# G         0.500000  0.500000
# M         0.700146  0.299854
# T         1.000000  0.000000

# %%
pd.crosstab(train_df['Deck'],train_df['Survived'],normalize='index').plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Deck'>

# %% [markdown]
# - 75% of Passengers from Deck B, D, E survived
# - More than 50% passengers (but less than 75%) from Deck B, F and G survived

# %% [markdown]
# ### Age
#
# **conclusions**
#
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist',bins=20)

# %%
df['Age'].plot(kind='kde')

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].plot(kind='box')

# %%
df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df['Age'].isnull().sum()/len(df['Age'])
# Out:
# 0.19865319865319866

# %% [markdown]
# ### Fare
#
# **conclusions**
#
# - The data is highly(positively) skewed
# - Fare col actually contains the group fare and not the individual fare(This migth be and issue)
# - We need to create a new col called individual fare

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')

# %%
df['Fare'].plot(kind='kde')

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %%
df['Fare'].plot(kind='box')

# %%
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### Survived
#
# **conclusions**
#
# - Parch and SibSp cols can be merged to form  a new col call family_size
# - Create a new col called is_alone

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar')

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%0.1f%%')

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100)

# %%
pd.crosstab(df['Survived'],df['Sex'],normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
pd.crosstab(df['Survived'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df['Sex'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df['Pclass'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
# survived and age

df[df['Survived'] == 1]['Age'].plot(kind='kde',label='Survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde',label='Not Survived')

plt.legend()
plt.show()

# %%
df[df['Pclass'] == 1]['Age'].mean()
# Out:
# 38.233440860215055

# %%
# Feature Engineering on Fare col

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df['Name'].str.contains('Sage')]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df1 = pd.read_csv('/content/test.csv')

# %%
df = pd.concat([df,df1])

# %%
df[df['Ticket'] == 'CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# ...

# %%
df['individual_fare'] = df['Fare']/(df['SibSp'] + df['Parch'] + 1)

# %%
df['individual_fare'].plot(kind='box')

# %%
df[['individual_fare','Fare']].describe()
# Out:
#        individual_fare         Fare
# count      1308.000000  1308.000000
# mean         20.518215    33.295479
# std          35.774337    51.758668
# min           0.000000     0.000000
# 25%           7.452767     7.895800
# 50%           8.512483    14.454200
# 75%          24.237500    31.275000
# max         512.329200   512.329200

# %%
df['Fare'].
# Out:
# 0        7.2500
# 1       71.2833
# 2        7.9250
# 3       53.1000
# 4        8.0500
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 1309, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['family_size'] = df['SibSp'] + df['Parch'] + 1

# %%
# family_type
# 1 -> alone
# 2-4 -> small
# >5 -> large

def transform_family_size(num):

  if num == 1:
    return 'alone'
  elif num>1 and num <5:
    return "small"
  else:
    return "large"

# %%
df['family_type'] = df['family_size'].apply(transform_family_size)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df['Survived'],df['family_type'],normalize='columns')*100
# Out:
# family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %%
df['surname'] = df['Name'].str.split(',').str.get(0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
temp_df = df[df['title'].isin(['Mr.','Miss.','Mrs.','Master.','ootherr'])]

# %%
pd.crosstab(temp_df['Survived'],temp_df['title'],normalize='columns')*100
# Out:
# title     Master.     Miss.        Mr.  Mrs.    ootherr
# Survived
# 0.0          42.5  30.21978  84.332689  20.8  72.222222
# 1.0          57.5  69.78022  15.667311  79.2  27.777778

# %%
df['title'] = df['title'].str.replace('Rev.','other')
df['title'] = df['title'].str.replace('Dr.','other')
df['title'] = df['title'].str.replace('Col.','other')
df['title'] = df['title'].str.replace('Major.','other')
df['title'] = df['title'].str.replace('Capt.','other')
df['title'] = df['title'].str.replace('the','other')
df['title'] = df['title'].str.replace('Jonkheer.','other')
# ,'Dr.','Col.','Major.','Don.','Capt.','the','Jonkheer.']
# Out:
# <ipython-input-124-ffb23deeff2c>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Rev.','other')
# <ipython-input-124-ffb23deeff2c>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Dr.','other')
# <ipython-input-124-ffb23deeff2c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Col.','other')
# <ipython-input-124-ffb23deeff2c>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Major.','other')
# <ipython-input-124-ffb23deeff2c>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Capt.','other')
# ...

# %%
df['Cabin'].isnull().sum()/len(df['Cabin'])
# Out:
# 0.774637127578304

# %%
df['Cabin'].fillna('M',inplace=True)

# %%
df['Cabin'].value_counts()
# Out:
# M                  1014
# C23 C25 C27           6
# B57 B59 B63 B66       5
# G6                    5
# F33                   4
#                    ...
# A14                   1
# E63                   1
# E12                   1
# E38                   1
# C105                  1
# Name: Cabin, Length: 187, dtype: int64

# %%
df['deck'] = df['Cabin'].str[0]

# %%
df['deck'].value_counts()
# Out:
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: deck, dtype: int64

# %%
pd.crosstab(df['deck'],df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df['deck'],df['Survived'],normalize='index').plot(kind='bar',stacked=True)

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(df1)

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...
